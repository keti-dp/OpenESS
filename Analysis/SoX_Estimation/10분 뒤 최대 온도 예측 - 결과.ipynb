# %%
# 10분 뒤 최대 전압 예측 - 결과.ipynb 참조

import pandas as pd
import os
from matplotlib import pyplot as plt
from datetime import datetime
import numpy as np


sel_features = ['hour','RACK_VOLTAGE','RACK_MIN_CELL_VOLTAGE','RACK_MIN_CELL_TEMPERATURE',
                'RACK_MAX_CELL_TEMPERATURE','RACK_CURRENT','minute','RACK_CELL_TEMPERATURE_GAP',
                'RACK_MAX_CELL_VOLTAGE','RACK_CELL_VOLTAGE_AVERAGE','RACK_CELL_VOLTAGE_GAP','day',
                'RACK_SOC','RACK_CELL_TEMPERATURE_AVERAGE']

label = "RACK_MAX_CELL_TEMPERATURE"

def date_range(start, end):
    start = datetime.strptime(start, "%Y%m%d")
    end = datetime.strptime(end, "%Y%m%d")
    dates = [date.strftime("%Y%m%d") for date in pd.date_range(start, periods=(end-start).days+1)]
    return dates

train_dates = date_range("20211001", "20220430")

path = "./forecasting_data/"

train = pd.DataFrame()

for train_date in train_dates:
    try:
        ess_data = pd.read_feather(path + train_date + "/rack.feather")[sel_features]

        train = pd.concat([train, ess_data], axis=0)
    except:
        pass

trainX = train.iloc[:-600,:]
trainY = train.reset_index(drop=True).loc[600:,label].reset_index(drop=True)

# %%
from datetime import datetime
import numpy as np



def date_range(start, end):
    start = datetime.strptime(start, "%Y%m%d")
    end = datetime.strptime(end, "%Y%m%d")
    dates = [date.strftime("%Y%m%d") for date in pd.date_range(start, periods=(end-start).days+1)]
    return dates

valid_dates = date_range("20220501", "20220630")

path = "./forecasting_data/"

valid = pd.DataFrame()

for valid_date in valid_dates:
    try:
        ess_data = pd.read_feather(path + valid_date + "/rack.feather")[sel_features]
        valid = pd.concat([valid, ess_data], axis=0)
    except:
        pass

validX = valid.iloc[:-600,:]
validY = valid.reset_index(drop=True).loc[600:,label].reset_index(drop=True)

# %%
lightGBM_param = {"learning_rate"                    : 0.05, 
                  "num_leaves"                       : 255,
                  "colsample_bytree"                 : 0.8466655445017455,
                  "subsample"                        : 0.8363223383173761,
                  "verbosity"                        : -1,
                  "random_state"                     : 42,
                  "objective"                        : "regression",
                  "metric"                           : "l2",
                  "num_threads"                      : 10,
                  "min_sum_hessian_in_leaf"          : 0.3139754544772033,
                  "reg_alpha"                        : 1.3918976712256577e-07,
                  "reg_lambda"                       : 0.015222751757854997,
                  "n_estimators"                     : 1000,
                  "max_depth "                       : 10
                 }

XGBoost_param = {"max_depth" : 4,
                 "learning_rate": 0.10261711125039377,
                 "n_estimators": 2000,
                 "colsample_bytree": 0.8306482536182962,
                 "colsample_bylevel": 0.5200894204312736,
                 "colsample_bynode": 0.9125155627018552,
                 "reg_lambda": 0.29449215771684206,
                 "reg_alpha": 0.019867959415002325,
                 "subsample": 0.85,
                 "min_child_weight": 9,
                 "gamma" : 0.1010776765952064,
                 "tree_method" : 'gpu_hist', 
                 "gpu_id" : 0
                }

#trainX = train.iloc[:-600,:].drop(["TIMESTAMP","BANK_ID","RACK_ID"], axis=1)
#trainY = train.reset_index(drop=True).loc[600:,"RACK_MAX_CELL_VOLTAGE"].reset_index(drop=True)

trainX, trainY = trainX.apply(pd.to_numeric), trainY.apply(pd.to_numeric)
validX, validY = validX.apply(pd.to_numeric), validY.apply(pd.to_numeric)

# %%
from lightgbm import LGBMRegressor

lgb_model = LGBMRegressor(**lightGBM_param)
lgb_model.fit(trainX, trainY)
# Out:
# [LightGBM] [Warning] max_depth is set=-1, max_depth= will be ignored. Current value: max_depth=-1
# [LightGBM] [Warning] Unknown parameter: 10
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.3139754544772033, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.3139754544772033
# [LightGBM] [Warning] num_threads is set=10, n_jobs=-1 will be ignored. Current value: num_threads=10
# LGBMRegressor(colsample_bytree=0.8466655445017455, learning_rate=0.05,
#               max_depth =10, metric='l2',
#               min_sum_hessian_in_leaf=0.3139754544772033, n_estimators=1000,
#               num_leaves=255, num_threads=10, objective='regression',
#               random_state=42, reg_alpha=1.3918976712256577e-07,
#               reg_lambda=0.015222751757854997, subsample=0.8363223383173761,
#               verbosity=-1)

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(**XGBoost_param)
xgb_model.fit(trainX,trainY)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree',
#              colsample_bylevel=0.5200894204312736,
#              colsample_bynode=0.9125155627018552,
#              colsample_bytree=0.8306482536182962, enable_categorical=False,
#              gamma=0.1010776765952064, gpu_id=0, importance_type=None,
#              interaction_constraints='', learning_rate=0.10261711125039377,
#              max_delta_step=0, max_depth=4, min_child_weight=9, missing=nan,
#              monotone_constraints='()', n_estimators=2000, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0.019867959415002325, reg_lambda=0.29449215771684206,
#              scale_pos_weight=1, subsample=0.85, tree_method='gpu_hist',
#              validate_parameters=1, verbosity=None)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression().fit(trainX, trainY)

# %%
from catboost import CatBoostRegressor

cat_model = CatBoostRegressor(task_type="GPU", devices='0:1').fit(trainX, trainY)
# Out:
# Learning rate set to 0.144712
# 0:	learn: 3.0975891	total: 74.4ms	remaining: 1m 14s
# 1:	learn: 2.6725478	total: 153ms	remaining: 1m 16s
# 2:	learn: 2.3073062	total: 229ms	remaining: 1m 16s
# 3:	learn: 1.9935277	total: 320ms	remaining: 1m 19s
# 4:	learn: 1.7207434	total: 395ms	remaining: 1m 18s
# 5:	learn: 1.4875313	total: 469ms	remaining: 1m 17s
# 6:	learn: 1.2876528	total: 553ms	remaining: 1m 18s
# 7:	learn: 1.1171598	total: 628ms	remaining: 1m 17s
# 8:	learn: 0.9682309	total: 704ms	remaining: 1m 17s
# 9:	learn: 0.8423558	total: 783ms	remaining: 1m 17s
# 10:	learn: 0.7342022	total: 858ms	remaining: 1m 17s
# 11:	learn: 0.6424606	total: 932ms	remaining: 1m 16s
# 12:	learn: 0.5637895	total: 1.01s	remaining: 1m 16s
# 13:	learn: 0.4965437	total: 1.08s	remaining: 1m 16s
# 14:	learn: 0.4406433	total: 1.16s	remaining: 1m 15s
# 15:	learn: 0.3919318	total: 1.24s	remaining: 1m 16s
# 16:	learn: 0.3503169	total: 1.31s	remaining: 1m 15s
# 62:	learn: 0.1097497	total: 4.9s	remaining: 1m 12s
# 63:	learn: 0.1093706	total: 4.98s	remaining: 1m 12s
# 64:	learn: 0.1090550	total: 5.06s	remaining: 1m 12s
# 65:	learn: 0.1077697	total: 5.13s	remaining: 1m 12s
# 66:	learn: 0.1075658	total: 5.21s	remaining: 1m 12s
# 67:	learn: 0.1071251	total: 5.29s	remaining: 1m 12s
# 68:	learn: 0.1069059	total: 5.37s	remaining: 1m 12s
# 69:	learn: 0.1065829	total: 5.45s	remaining: 1m 12s
# 70:	learn: 0.1063183	total: 5.53s	remaining: 1m 12s
# 71:	learn: 0.1061560	total: 5.6s	remaining: 1m 12s
# 72:	learn: 0.1059164	total: 5.68s	remaining: 1m 12s
# 73:	learn: 0.1057417	total: 5.76s	remaining: 1m 12s
# 74:	learn: 0.1056468	total: 5.83s	remaining: 1m 11s
# 75:	learn: 0.1053209	total: 5.91s	remaining: 1m 11s
# 76:	learn: 0.1051654	total: 5.99s	remaining: 1m 11s
# 77:	learn: 0.1032452	total: 6.06s	remaining: 1m 11s
# 78:	learn: 0.1030423	total: 6.16s	remaining: 1m 11s
# 79:	learn: 0.1028137	total: 6.23s	remaining: 1m 11s
# 80:	learn: 0.1026103	total: 6.3s	remaining: 1m 11s
# 81:	learn: 0.1024124	total: 6.37s	remaining: 1m 11s
# 82:	learn: 0.1018451	total: 6.46s	remaining: 1m 11s
# 83:	learn: 0.1017041	total: 6.54s	remaining: 1m 11s
# 84:	learn: 0.1002370	total: 6.62s	remaining: 1m 11s
# 85:	learn: 0.0999022	total: 6.7s	remaining: 1m 11s
# 86:	learn: 0.0995201	total: 6.77s	remaining: 1m 11s
# 87:	learn: 0.0992907	total: 6.85s	remaining: 1m 11s
# 88:	learn: 0.0991539	total: 6.93s	remaining: 1m 10s
# 89:	learn: 0.0990425	total: 7.01s	remaining: 1m 10s
# 90:	learn: 0.0989132	total: 7.09s	remaining: 1m 10s
# 91:	learn: 0.0987748	total: 7.17s	remaining: 1m 10s
# 92:	learn: 0.0985649	total: 7.24s	remaining: 1m 10s
# 93:	learn: 0.0984868	total: 7.33s	remaining: 1m 10s
# 94:	learn: 0.0983870	total: 7.4s	remaining: 1m 10s
# 95:	learn: 0.0981818	total: 7.48s	remaining: 1m 10s
# 96:	learn: 0.0981043	total: 7.55s	remaining: 1m 10s
# 97:	learn: 0.0977551	total: 7.63s	remaining: 1m 10s
# 98:	learn: 0.0976610	total: 7.71s	remaining: 1m 10s
# 99:	learn: 0.0975091	total: 7.78s	remaining: 1m 10s
# 100:	learn: 0.0972523	total: 7.86s	remaining: 1m 9s
# 101:	learn: 0.0971102	total: 7.93s	remaining: 1m 9s
# 102:	learn: 0.0969928	total: 8.01s	remaining: 1m 9s
# 103:	learn: 0.0968529	total: 8.09s	remaining: 1m 9s
# 104:	learn: 0.0967403	total: 8.17s	remaining: 1m 9s
# 105:	learn: 0.0966017	total: 8.27s	remaining: 1m 9s
# 106:	learn: 0.0963933	total: 8.34s	remaining: 1m 9s
# 107:	learn: 0.0962420	total: 8.41s	remaining: 1m 9s
# 108:	learn: 0.0960551	total: 8.49s	remaining: 1m 9s
# 109:	learn: 0.0957941	total: 8.56s	remaining: 1m 9s
# 110:	learn: 0.0957369	total: 8.64s	remaining: 1m 9s
# 111:	learn: 0.0954958	total: 8.72s	remaining: 1m 9s
# 112:	learn: 0.0953281	total: 8.79s	remaining: 1m 9s
# 113:	learn: 0.0951334	total: 8.87s	remaining: 1m 8s
# 114:	learn: 0.0950397	total: 8.96s	remaining: 1m 8s
# 115:	learn: 0.0949602	total: 9.03s	remaining: 1m 8s
# 116:	learn: 0.0948756	total: 9.1s	remaining: 1m 8s
# 117:	learn: 0.0948046	total: 9.18s	remaining: 1m 8s
# 118:	learn: 0.0946632	total: 9.25s	remaining: 1m 8s
# 119:	learn: 0.0944411	total: 9.33s	remaining: 1m 8s
# 120:	learn: 0.0943284	total: 9.4s	remaining: 1m 8s
# 121:	learn: 0.0942296	total: 9.47s	remaining: 1m 8s
# 122:	learn: 0.0925209	total: 9.54s	remaining: 1m 8s
# 123:	learn: 0.0924050	total: 9.62s	remaining: 1m 7s
# 124:	learn: 0.0923090	total: 9.7s	remaining: 1m 7s
# 125:	learn: 0.0922596	total: 9.77s	remaining: 1m 7s
# 126:	learn: 0.0920559	total: 9.85s	remaining: 1m 7s
# 127:	learn: 0.0919920	total: 9.92s	remaining: 1m 7s
# 128:	learn: 0.0918527	total: 10s	remaining: 1m 7s
# 129:	learn: 0.0918040	total: 10.1s	remaining: 1m 7s
# 130:	learn: 0.0915205	total: 10.2s	remaining: 1m 7s
# 131:	learn: 0.0914233	total: 10.2s	remaining: 1m 7s
# 132:	learn: 0.0913191	total: 10.3s	remaining: 1m 7s
# 133:	learn: 0.0911308	total: 10.4s	remaining: 1m 7s
# 134:	learn: 0.0910548	total: 10.5s	remaining: 1m 7s
# 135:	learn: 0.0909657	total: 10.5s	remaining: 1m 6s
# 136:	learn: 0.0907237	total: 10.6s	remaining: 1m 6s
# 137:	learn: 0.0906399	total: 10.7s	remaining: 1m 6s
# 138:	learn: 0.0905124	total: 10.8s	remaining: 1m 6s
# 139:	learn: 0.0903700	total: 10.9s	remaining: 1m 6s
# 140:	learn: 0.0901821	total: 10.9s	remaining: 1m 6s
# 141:	learn: 0.0899906	total: 11s	remaining: 1m 6s
# 142:	learn: 0.0899239	total: 11.1s	remaining: 1m 6s
# 143:	learn: 0.0898709	total: 11.2s	remaining: 1m 6s
# 144:	learn: 0.0897746	total: 11.2s	remaining: 1m 6s
# 145:	learn: 0.0884831	total: 11.3s	remaining: 1m 6s
# 146:	learn: 0.0884014	total: 11.4s	remaining: 1m 6s
# 147:	learn: 0.0883210	total: 11.5s	remaining: 1m 5s
# 148:	learn: 0.0882823	total: 11.5s	remaining: 1m 5s
# 149:	learn: 0.0882197	total: 11.6s	remaining: 1m 5s
# 150:	learn: 0.0880873	total: 11.7s	remaining: 1m 5s
# 151:	learn: 0.0879947	total: 11.8s	remaining: 1m 5s
# 152:	learn: 0.0879250	total: 11.8s	remaining: 1m 5s
# 153:	learn: 0.0878719	total: 11.9s	remaining: 1m 5s
# 154:	learn: 0.0878099	total: 12s	remaining: 1m 5s
# 155:	learn: 0.0876021	total: 12.1s	remaining: 1m 5s
# 156:	learn: 0.0875697	total: 12.2s	remaining: 1m 5s
# 157:	learn: 0.0875238	total: 12.3s	remaining: 1m 5s
# 158:	learn: 0.0874112	total: 12.3s	remaining: 1m 5s
# 159:	learn: 0.0873113	total: 12.4s	remaining: 1m 5s
# 160:	learn: 0.0871832	total: 12.5s	remaining: 1m 5s
# 161:	learn: 0.0870547	total: 12.6s	remaining: 1m 4s
# 162:	learn: 0.0869805	total: 12.6s	remaining: 1m 4s
# 163:	learn: 0.0868846	total: 12.7s	remaining: 1m 4s
# 164:	learn: 0.0868268	total: 12.8s	remaining: 1m 4s
# 165:	learn: 0.0865315	total: 12.9s	remaining: 1m 4s
# 166:	learn: 0.0858924	total: 12.9s	remaining: 1m 4s
# 167:	learn: 0.0857962	total: 13s	remaining: 1m 4s
# 168:	learn: 0.0857274	total: 13.1s	remaining: 1m 4s
# 169:	learn: 0.0856672	total: 13.2s	remaining: 1m 4s
# 170:	learn: 0.0856193	total: 13.2s	remaining: 1m 4s
# 171:	learn: 0.0855465	total: 13.3s	remaining: 1m 4s
# 172:	learn: 0.0854881	total: 13.4s	remaining: 1m 4s
# 173:	learn: 0.0854290	total: 13.5s	remaining: 1m 4s
# 174:	learn: 0.0853866	total: 13.6s	remaining: 1m 3s
# 175:	learn: 0.0837569	total: 13.6s	remaining: 1m 3s
# 176:	learn: 0.0836699	total: 13.7s	remaining: 1m 3s
# 177:	learn: 0.0836066	total: 13.8s	remaining: 1m 3s
# 178:	learn: 0.0835616	total: 13.9s	remaining: 1m 3s
# 179:	learn: 0.0834658	total: 14s	remaining: 1m 3s
# 180:	learn: 0.0833805	total: 14.1s	remaining: 1m 3s
# 181:	learn: 0.0831295	total: 14.1s	remaining: 1m 3s
# 182:	learn: 0.0822112	total: 14.2s	remaining: 1m 3s
# 183:	learn: 0.0821485	total: 14.3s	remaining: 1m 3s
# 184:	learn: 0.0821173	total: 14.4s	remaining: 1m 3s
# 185:	learn: 0.0819500	total: 14.4s	remaining: 1m 3s
# 186:	learn: 0.0819166	total: 14.5s	remaining: 1m 3s
# 187:	learn: 0.0818545	total: 14.6s	remaining: 1m 3s
# 188:	learn: 0.0817556	total: 14.7s	remaining: 1m 2s
# 189:	learn: 0.0816785	total: 14.7s	remaining: 1m 2s
# 190:	learn: 0.0816365	total: 14.8s	remaining: 1m 2s
# 191:	learn: 0.0815859	total: 14.9s	remaining: 1m 2s
# 192:	learn: 0.0814951	total: 15s	remaining: 1m 2s
# 193:	learn: 0.0814639	total: 15.1s	remaining: 1m 2s
# 194:	learn: 0.0814228	total: 15.1s	remaining: 1m 2s
# 335:	learn: 0.0691253	total: 26.1s	remaining: 51.6s
# 336:	learn: 0.0691017	total: 26.2s	remaining: 51.6s
# 337:	learn: 0.0690786	total: 26.3s	remaining: 51.5s
# 338:	learn: 0.0690522	total: 26.4s	remaining: 51.4s
# 339:	learn: 0.0689815	total: 26.4s	remaining: 51.3s
# 340:	learn: 0.0689522	total: 26.5s	remaining: 51.2s
# 341:	learn: 0.0689166	total: 26.6s	remaining: 51.2s
# 342:	learn: 0.0688904	total: 26.7s	remaining: 51.1s
# 343:	learn: 0.0688553	total: 26.8s	remaining: 51s
# 344:	learn: 0.0688052	total: 26.8s	remaining: 50.9s
# 345:	learn: 0.0687793	total: 26.9s	remaining: 50.9s
# 346:	learn: 0.0687529	total: 27s	remaining: 50.8s
# 347:	learn: 0.0687272	total: 27.1s	remaining: 50.7s
# 348:	learn: 0.0686927	total: 27.1s	remaining: 50.6s
# 349:	learn: 0.0686634	total: 27.2s	remaining: 50.6s
# 350:	learn: 0.0685331	total: 27.3s	remaining: 50.5s
# 351:	learn: 0.0684996	total: 27.4s	remaining: 50.4s
# 352:	learn: 0.0684722	total: 27.5s	remaining: 50.3s
# 353:	learn: 0.0684467	total: 27.5s	remaining: 50.2s
# 354:	learn: 0.0684104	total: 27.6s	remaining: 50.2s
# 355:	learn: 0.0682334	total: 27.7s	remaining: 50.1s
# 356:	learn: 0.0681056	total: 27.8s	remaining: 50s
# 357:	learn: 0.0679702	total: 27.8s	remaining: 49.9s
# 358:	learn: 0.0679438	total: 27.9s	remaining: 49.8s
# 359:	learn: 0.0679227	total: 28s	remaining: 49.8s
# 360:	learn: 0.0679016	total: 28.1s	remaining: 49.7s
# 361:	learn: 0.0678815	total: 28.1s	remaining: 49.6s
# 362:	learn: 0.0678223	total: 28.2s	remaining: 49.5s
# 363:	learn: 0.0678030	total: 28.3s	remaining: 49.5s
# 364:	learn: 0.0670251	total: 28.4s	remaining: 49.4s
# 365:	learn: 0.0669816	total: 28.5s	remaining: 49.3s
# 366:	learn: 0.0669574	total: 28.5s	remaining: 49.2s
# 367:	learn: 0.0669276	total: 28.6s	remaining: 49.1s
# 368:	learn: 0.0669102	total: 28.7s	remaining: 49.1s
# 369:	learn: 0.0668899	total: 28.8s	remaining: 49s
# 370:	learn: 0.0668716	total: 28.8s	remaining: 48.9s
# 371:	learn: 0.0668329	total: 28.9s	remaining: 48.8s
# 372:	learn: 0.0664869	total: 29s	remaining: 48.7s
# 373:	learn: 0.0664559	total: 29.1s	remaining: 48.6s
# 374:	learn: 0.0664048	total: 29.1s	remaining: 48.6s
# 375:	learn: 0.0663723	total: 29.2s	remaining: 48.5s
# 376:	learn: 0.0663457	total: 29.3s	remaining: 48.4s
# 377:	learn: 0.0663286	total: 29.4s	remaining: 48.3s
# 378:	learn: 0.0662874	total: 29.5s	remaining: 48.3s
# 379:	learn: 0.0662393	total: 29.5s	remaining: 48.2s
# 380:	learn: 0.0662112	total: 29.6s	remaining: 48.1s
# 613:	learn: 0.0576259	total: 48s	remaining: 30.2s
# 614:	learn: 0.0576083	total: 48.1s	remaining: 30.1s
# 615:	learn: 0.0575984	total: 48.2s	remaining: 30s
# 616:	learn: 0.0575893	total: 48.2s	remaining: 29.9s
# 617:	learn: 0.0575815	total: 48.3s	remaining: 29.9s
# 618:	learn: 0.0575701	total: 48.4s	remaining: 29.8s
# 619:	learn: 0.0575579	total: 48.5s	remaining: 29.7s
# 620:	learn: 0.0575362	total: 48.6s	remaining: 29.6s
# 621:	learn: 0.0575266	total: 48.6s	remaining: 29.6s
# 622:	learn: 0.0575201	total: 48.7s	remaining: 29.5s
# 623:	learn: 0.0575101	total: 48.8s	remaining: 29.4s
# 624:	learn: 0.0575038	total: 48.9s	remaining: 29.3s
# 625:	learn: 0.0574917	total: 49s	remaining: 29.2s
# 626:	learn: 0.0574784	total: 49s	remaining: 29.2s
# 627:	learn: 0.0574649	total: 49.1s	remaining: 29.1s
# 628:	learn: 0.0574566	total: 49.2s	remaining: 29s
# 629:	learn: 0.0574426	total: 49.3s	remaining: 28.9s
# 630:	learn: 0.0574261	total: 49.3s	remaining: 28.8s
# 631:	learn: 0.0574136	total: 49.4s	remaining: 28.8s
# 632:	learn: 0.0573966	total: 49.5s	remaining: 28.7s
# 633:	learn: 0.0573809	total: 49.6s	remaining: 28.6s
# 634:	learn: 0.0573711	total: 49.7s	remaining: 28.5s
# 635:	learn: 0.0573612	total: 49.7s	remaining: 28.5s
# 636:	learn: 0.0573504	total: 49.8s	remaining: 28.4s
# 637:	learn: 0.0573419	total: 49.9s	remaining: 28.3s
# 638:	learn: 0.0573241	total: 50s	remaining: 28.2s
# 639:	learn: 0.0573151	total: 50.1s	remaining: 28.2s
# 640:	learn: 0.0572544	total: 50.1s	remaining: 28.1s
# 641:	learn: 0.0572459	total: 50.2s	remaining: 28s
# 642:	learn: 0.0572373	total: 50.3s	remaining: 27.9s
# 643:	learn: 0.0572187	total: 50.4s	remaining: 27.8s
# 644:	learn: 0.0572109	total: 50.4s	remaining: 27.8s
# 645:	learn: 0.0572000	total: 50.5s	remaining: 27.7s
# 646:	learn: 0.0571922	total: 50.6s	remaining: 27.6s
# 647:	learn: 0.0571818	total: 50.7s	remaining: 27.5s
# 648:	learn: 0.0571697	total: 50.8s	remaining: 27.5s
# 649:	learn: 0.0571622	total: 50.8s	remaining: 27.4s
# 650:	learn: 0.0571347	total: 50.9s	remaining: 27.3s
# 651:	learn: 0.0571288	total: 51s	remaining: 27.2s
# 652:	learn: 0.0571201	total: 51.1s	remaining: 27.1s
# 653:	learn: 0.0571070	total: 51.2s	remaining: 27.1s
# 654:	learn: 0.0570945	total: 51.2s	remaining: 27s
# 655:	learn: 0.0570819	total: 51.3s	remaining: 26.9s
# 656:	learn: 0.0570710	total: 51.4s	remaining: 26.8s
# 657:	learn: 0.0570557	total: 51.5s	remaining: 26.8s
# 658:	learn: 0.0570451	total: 51.6s	remaining: 26.7s
# 659:	learn: 0.0570340	total: 51.7s	remaining: 26.6s
# 660:	learn: 0.0570232	total: 51.8s	remaining: 26.5s
# 661:	learn: 0.0570139	total: 51.8s	remaining: 26.5s
# 662:	learn: 0.0570012	total: 51.9s	remaining: 26.4s
# 663:	learn: 0.0569908	total: 52s	remaining: 26.3s
# 664:	learn: 0.0569824	total: 52.1s	remaining: 26.2s
# 665:	learn: 0.0569746	total: 52.1s	remaining: 26.1s
# 666:	learn: 0.0569665	total: 52.2s	remaining: 26.1s
# 667:	learn: 0.0569564	total: 52.3s	remaining: 26s
# 668:	learn: 0.0569511	total: 52.4s	remaining: 25.9s
# 669:	learn: 0.0569448	total: 52.5s	remaining: 25.8s
# 670:	learn: 0.0569374	total: 52.5s	remaining: 25.8s
# 671:	learn: 0.0569200	total: 52.6s	remaining: 25.7s
# 672:	learn: 0.0569089	total: 52.7s	remaining: 25.6s
# 673:	learn: 0.0568980	total: 52.8s	remaining: 25.5s
# 674:	learn: 0.0568909	total: 52.9s	remaining: 25.5s
# 675:	learn: 0.0568786	total: 52.9s	remaining: 25.4s
# 676:	learn: 0.0568651	total: 53s	remaining: 25.3s
# 677:	learn: 0.0568567	total: 53.1s	remaining: 25.2s
# 678:	learn: 0.0568435	total: 53.2s	remaining: 25.1s
# 679:	learn: 0.0567801	total: 53.3s	remaining: 25.1s
# 680:	learn: 0.0567704	total: 53.4s	remaining: 25s
# 681:	learn: 0.0567621	total: 53.5s	remaining: 24.9s
# 682:	learn: 0.0566622	total: 53.6s	remaining: 24.9s
# 683:	learn: 0.0566467	total: 53.7s	remaining: 24.8s
# 684:	learn: 0.0566332	total: 53.7s	remaining: 24.7s
# 685:	learn: 0.0566238	total: 53.8s	remaining: 24.6s
# 686:	learn: 0.0566081	total: 53.9s	remaining: 24.6s
# 687:	learn: 0.0565952	total: 54s	remaining: 24.5s
# 688:	learn: 0.0565806	total: 54s	remaining: 24.4s
# 689:	learn: 0.0565735	total: 54.1s	remaining: 24.3s
# 690:	learn: 0.0565625	total: 54.2s	remaining: 24.2s
# 691:	learn: 0.0565473	total: 54.3s	remaining: 24.2s
# 692:	learn: 0.0565334	total: 54.4s	remaining: 24.1s
# 693:	learn: 0.0565248	total: 54.5s	remaining: 24s
# 694:	learn: 0.0565165	total: 54.6s	remaining: 23.9s
# 695:	learn: 0.0565075	total: 54.6s	remaining: 23.9s
# 696:	learn: 0.0564929	total: 54.7s	remaining: 23.8s
# 697:	learn: 0.0564818	total: 54.8s	remaining: 23.7s
# 698:	learn: 0.0564708	total: 54.9s	remaining: 23.6s
# 699:	learn: 0.0564612	total: 54.9s	remaining: 23.5s
# 700:	learn: 0.0564444	total: 55s	remaining: 23.5s
# 701:	learn: 0.0564355	total: 55.1s	remaining: 23.4s
# 702:	learn: 0.0564138	total: 55.2s	remaining: 23.3s
# 703:	learn: 0.0564053	total: 55.3s	remaining: 23.2s
# 704:	learn: 0.0563094	total: 55.3s	remaining: 23.2s
# 705:	learn: 0.0562947	total: 55.5s	remaining: 23.1s
# 752:	learn: 0.0550998	total: 59.2s	remaining: 19.4s
# 753:	learn: 0.0550884	total: 59.3s	remaining: 19.3s
# 754:	learn: 0.0550805	total: 59.4s	remaining: 19.3s
# 755:	learn: 0.0550714	total: 59.4s	remaining: 19.2s
# 756:	learn: 0.0550632	total: 59.5s	remaining: 19.1s
# 757:	learn: 0.0550490	total: 59.6s	remaining: 19s
# 758:	learn: 0.0550399	total: 59.7s	remaining: 18.9s
# 759:	learn: 0.0550312	total: 59.8s	remaining: 18.9s
# 760:	learn: 0.0550235	total: 59.8s	remaining: 18.8s
# 761:	learn: 0.0550100	total: 59.9s	remaining: 18.7s
# 762:	learn: 0.0550045	total: 60s	remaining: 18.6s
# 763:	learn: 0.0549964	total: 1m	remaining: 18.6s
# 764:	learn: 0.0549900	total: 1m	remaining: 18.5s
# 765:	learn: 0.0549835	total: 1m	remaining: 18.4s
# 766:	learn: 0.0549781	total: 1m	remaining: 18.3s
# 767:	learn: 0.0549728	total: 1m	remaining: 18.2s
# 768:	learn: 0.0549623	total: 1m	remaining: 18.2s
# 769:	learn: 0.0549504	total: 1m	remaining: 18.1s
# 770:	learn: 0.0549439	total: 1m	remaining: 18s
# 771:	learn: 0.0549366	total: 1m	remaining: 17.9s
# 772:	learn: 0.0549087	total: 1m	remaining: 17.8s
# 773:	learn: 0.0549009	total: 1m	remaining: 17.8s
# 774:	learn: 0.0548910	total: 1m	remaining: 17.7s
# 775:	learn: 0.0548819	total: 1m 1s	remaining: 17.6s
# 776:	learn: 0.0548717	total: 1m 1s	remaining: 17.5s
# 777:	learn: 0.0548586	total: 1m 1s	remaining: 17.5s
# 778:	learn: 0.0548492	total: 1m 1s	remaining: 17.4s
# 779:	learn: 0.0548337	total: 1m 1s	remaining: 17.3s
# 780:	learn: 0.0547746	total: 1m 1s	remaining: 17.2s
# 781:	learn: 0.0546930	total: 1m 1s	remaining: 17.1s
# 782:	learn: 0.0546849	total: 1m 1s	remaining: 17.1s
# 783:	learn: 0.0546734	total: 1m 1s	remaining: 17s
# 784:	learn: 0.0546654	total: 1m 1s	remaining: 16.9s
# 785:	learn: 0.0546562	total: 1m 1s	remaining: 16.8s
# 786:	learn: 0.0546482	total: 1m 1s	remaining: 16.8s
# 787:	learn: 0.0546381	total: 1m 1s	remaining: 16.7s
# 788:	learn: 0.0546317	total: 1m 2s	remaining: 16.6s
# 789:	learn: 0.0546265	total: 1m 2s	remaining: 16.5s
# 790:	learn: 0.0546184	total: 1m 2s	remaining: 16.4s
# 791:	learn: 0.0546045	total: 1m 2s	remaining: 16.4s
# 792:	learn: 0.0543459	total: 1m 2s	remaining: 16.3s
# 793:	learn: 0.0543349	total: 1m 2s	remaining: 16.2s
# 794:	learn: 0.0543265	total: 1m 2s	remaining: 16.1s
# 795:	learn: 0.0543121	total: 1m 2s	remaining: 16s
# 796:	learn: 0.0543059	total: 1m 2s	remaining: 16s
# 797:	learn: 0.0542953	total: 1m 2s	remaining: 15.9s
# 798:	learn: 0.0542877	total: 1m 2s	remaining: 15.8s
# 799:	learn: 0.0542776	total: 1m 2s	remaining: 15.7s
# 800:	learn: 0.0542683	total: 1m 2s	remaining: 15.6s
# 801:	learn: 0.0542605	total: 1m 3s	remaining: 15.6s
# 802:	learn: 0.0542552	total: 1m 3s	remaining: 15.5s
# 803:	learn: 0.0542476	total: 1m 3s	remaining: 15.4s
# 804:	learn: 0.0542441	total: 1m 3s	remaining: 15.3s
# 805:	learn: 0.0542393	total: 1m 3s	remaining: 15.3s
# 806:	learn: 0.0542332	total: 1m 3s	remaining: 15.2s
# 807:	learn: 0.0542251	total: 1m 3s	remaining: 15.1s
# 808:	learn: 0.0542148	total: 1m 3s	remaining: 15s
# 809:	learn: 0.0542076	total: 1m 3s	remaining: 14.9s
# 810:	learn: 0.0541988	total: 1m 3s	remaining: 14.9s
# 811:	learn: 0.0541904	total: 1m 3s	remaining: 14.8s
# 812:	learn: 0.0541798	total: 1m 3s	remaining: 14.7s
# 813:	learn: 0.0541722	total: 1m 4s	remaining: 14.6s
# 814:	learn: 0.0541643	total: 1m 4s	remaining: 14.5s
# 815:	learn: 0.0541553	total: 1m 4s	remaining: 14.5s
# 816:	learn: 0.0541433	total: 1m 4s	remaining: 14.4s
# 817:	learn: 0.0541305	total: 1m 4s	remaining: 14.3s
# 818:	learn: 0.0541182	total: 1m 4s	remaining: 14.2s
# 819:	learn: 0.0540802	total: 1m 4s	remaining: 14.2s
# 820:	learn: 0.0539879	total: 1m 4s	remaining: 14.1s
# 821:	learn: 0.0539826	total: 1m 4s	remaining: 14s
# 822:	learn: 0.0539732	total: 1m 4s	remaining: 13.9s
# 823:	learn: 0.0539647	total: 1m 4s	remaining: 13.8s
# 824:	learn: 0.0539579	total: 1m 4s	remaining: 13.8s
# 825:	learn: 0.0539476	total: 1m 4s	remaining: 13.7s
# 826:	learn: 0.0539368	total: 1m 5s	remaining: 13.6s
# 827:	learn: 0.0539240	total: 1m 5s	remaining: 13.5s
# 828:	learn: 0.0539176	total: 1m 5s	remaining: 13.4s
# 829:	learn: 0.0539069	total: 1m 5s	remaining: 13.4s
# 830:	learn: 0.0538959	total: 1m 5s	remaining: 13.3s
# 831:	learn: 0.0538895	total: 1m 5s	remaining: 13.2s
# 832:	learn: 0.0538831	total: 1m 5s	remaining: 13.1s
# 833:	learn: 0.0538740	total: 1m 5s	remaining: 13.1s
# 834:	learn: 0.0538654	total: 1m 5s	remaining: 13s
# 835:	learn: 0.0538604	total: 1m 5s	remaining: 12.9s
# 836:	learn: 0.0538544	total: 1m 5s	remaining: 12.8s
# 837:	learn: 0.0538113	total: 1m 5s	remaining: 12.7s
# 838:	learn: 0.0538028	total: 1m 5s	remaining: 12.7s
# 839:	learn: 0.0537935	total: 1m 6s	remaining: 12.6s
# 840:	learn: 0.0537891	total: 1m 6s	remaining: 12.5s
# 841:	learn: 0.0537823	total: 1m 6s	remaining: 12.4s
# 842:	learn: 0.0537740	total: 1m 6s	remaining: 12.3s
# 843:	learn: 0.0537683	total: 1m 6s	remaining: 12.3s
# 844:	learn: 0.0537604	total: 1m 6s	remaining: 12.2s
# 845:	learn: 0.0537517	total: 1m 6s	remaining: 12.1s
# 846:	learn: 0.0537408	total: 1m 6s	remaining: 12s
# 847:	learn: 0.0537330	total: 1m 6s	remaining: 12s
# 848:	learn: 0.0537260	total: 1m 6s	remaining: 11.9s
# 849:	learn: 0.0537149	total: 1m 6s	remaining: 11.8s
# 850:	learn: 0.0537075	total: 1m 6s	remaining: 11.7s
# 851:	learn: 0.0537000	total: 1m 7s	remaining: 11.6s
# 852:	learn: 0.0536867	total: 1m 7s	remaining: 11.6s
# 853:	learn: 0.0536795	total: 1m 7s	remaining: 11.5s
# 854:	learn: 0.0536721	total: 1m 7s	remaining: 11.4s
# 855:	learn: 0.0536667	total: 1m 7s	remaining: 11.3s
# 856:	learn: 0.0536589	total: 1m 7s	remaining: 11.2s
# 857:	learn: 0.0536495	total: 1m 7s	remaining: 11.2s
# 858:	learn: 0.0536434	total: 1m 7s	remaining: 11.1s
# 859:	learn: 0.0536368	total: 1m 7s	remaining: 11s
# 860:	learn: 0.0536312	total: 1m 7s	remaining: 10.9s
# 861:	learn: 0.0536266	total: 1m 7s	remaining: 10.9s
# 862:	learn: 0.0536211	total: 1m 7s	remaining: 10.8s
# 863:	learn: 0.0536151	total: 1m 7s	remaining: 10.7s
# 864:	learn: 0.0536099	total: 1m 8s	remaining: 10.6s
# 865:	learn: 0.0536009	total: 1m 8s	remaining: 10.5s
# 866:	learn: 0.0535903	total: 1m 8s	remaining: 10.5s
# 867:	learn: 0.0535827	total: 1m 8s	remaining: 10.4s
# 868:	learn: 0.0535742	total: 1m 8s	remaining: 10.3s
# 869:	learn: 0.0535553	total: 1m 8s	remaining: 10.2s
# 870:	learn: 0.0535350	total: 1m 8s	remaining: 10.2s
# 871:	learn: 0.0534891	total: 1m 8s	remaining: 10.1s
# 872:	learn: 0.0534823	total: 1m 8s	remaining: 9.99s
# 873:	learn: 0.0534740	total: 1m 8s	remaining: 9.91s
# 874:	learn: 0.0534149	total: 1m 8s	remaining: 9.84s
# 875:	learn: 0.0534091	total: 1m 8s	remaining: 9.76s
# 876:	learn: 0.0534034	total: 1m 9s	remaining: 9.68s
# 877:	learn: 0.0533890	total: 1m 9s	remaining: 9.6s
# 878:	learn: 0.0533811	total: 1m 9s	remaining: 9.52s
# 879:	learn: 0.0533744	total: 1m 9s	remaining: 9.44s
# 880:	learn: 0.0533657	total: 1m 9s	remaining: 9.37s
# 881:	learn: 0.0533590	total: 1m 9s	remaining: 9.29s
# 882:	learn: 0.0533489	total: 1m 9s	remaining: 9.21s
# 883:	learn: 0.0533438	total: 1m 9s	remaining: 9.13s
# 884:	learn: 0.0533291	total: 1m 9s	remaining: 9.05s
# 885:	learn: 0.0533217	total: 1m 9s	remaining: 8.97s
# 886:	learn: 0.0533152	total: 1m 9s	remaining: 8.89s
# 887:	learn: 0.0533089	total: 1m 9s	remaining: 8.81s
# 888:	learn: 0.0532998	total: 1m 9s	remaining: 8.73s
# 889:	learn: 0.0532962	total: 1m 10s	remaining: 8.65s
# 890:	learn: 0.0532892	total: 1m 10s	remaining: 8.58s
# 891:	learn: 0.0532850	total: 1m 10s	remaining: 8.5s
# 892:	learn: 0.0532768	total: 1m 10s	remaining: 8.42s
# 893:	learn: 0.0532674	total: 1m 10s	remaining: 8.34s
# 894:	learn: 0.0532620	total: 1m 10s	remaining: 8.26s
# 895:	learn: 0.0532567	total: 1m 10s	remaining: 8.18s
# 896:	learn: 0.0532421	total: 1m 10s	remaining: 8.1s
# 897:	learn: 0.0532347	total: 1m 10s	remaining: 8.03s
# 898:	learn: 0.0532258	total: 1m 10s	remaining: 7.95s
# 899:	learn: 0.0532166	total: 1m 10s	remaining: 7.87s
# 900:	learn: 0.0532093	total: 1m 10s	remaining: 7.79s
# 901:	learn: 0.0532037	total: 1m 10s	remaining: 7.71s
# 902:	learn: 0.0531972	total: 1m 11s	remaining: 7.63s
# 903:	learn: 0.0531914	total: 1m 11s	remaining: 7.55s
# 904:	learn: 0.0531861	total: 1m 11s	remaining: 7.48s
# 905:	learn: 0.0531814	total: 1m 11s	remaining: 7.4s
# 906:	learn: 0.0531747	total: 1m 11s	remaining: 7.32s
# 907:	learn: 0.0531668	total: 1m 11s	remaining: 7.24s
# 908:	learn: 0.0531611	total: 1m 11s	remaining: 7.16s
# 909:	learn: 0.0531555	total: 1m 11s	remaining: 7.08s
# 910:	learn: 0.0531419	total: 1m 11s	remaining: 7s
# 911:	learn: 0.0531348	total: 1m 11s	remaining: 6.93s
# 912:	learn: 0.0531295	total: 1m 11s	remaining: 6.85s
# 913:	learn: 0.0531248	total: 1m 11s	remaining: 6.77s
# 914:	learn: 0.0531185	total: 1m 12s	remaining: 6.69s
# 915:	learn: 0.0531138	total: 1m 12s	remaining: 6.61s
# 916:	learn: 0.0531053	total: 1m 12s	remaining: 6.53s
# 917:	learn: 0.0531000	total: 1m 12s	remaining: 6.46s
# 918:	learn: 0.0530875	total: 1m 12s	remaining: 6.38s
# 919:	learn: 0.0530811	total: 1m 12s	remaining: 6.3s
# 920:	learn: 0.0530747	total: 1m 12s	remaining: 6.22s
# 921:	learn: 0.0530661	total: 1m 12s	remaining: 6.14s
# 922:	learn: 0.0530625	total: 1m 12s	remaining: 6.06s
# 923:	learn: 0.0530551	total: 1m 12s	remaining: 5.98s
# 924:	learn: 0.0530446	total: 1m 12s	remaining: 5.91s
# 925:	learn: 0.0530378	total: 1m 12s	remaining: 5.83s
# 926:	learn: 0.0530243	total: 1m 12s	remaining: 5.75s
# 927:	learn: 0.0530172	total: 1m 13s	remaining: 5.67s
# 928:	learn: 0.0530077	total: 1m 13s	remaining: 5.59s
# 929:	learn: 0.0529789	total: 1m 13s	remaining: 5.51s
# 930:	learn: 0.0527928	total: 1m 13s	remaining: 5.43s
# 931:	learn: 0.0527881	total: 1m 13s	remaining: 5.36s
# 932:	learn: 0.0527524	total: 1m 13s	remaining: 5.28s
# 933:	learn: 0.0527478	total: 1m 13s	remaining: 5.2s
# 934:	learn: 0.0527407	total: 1m 13s	remaining: 5.12s
# 935:	learn: 0.0527309	total: 1m 13s	remaining: 5.04s
# 936:	learn: 0.0527249	total: 1m 13s	remaining: 4.96s
# 937:	learn: 0.0527207	total: 1m 13s	remaining: 4.88s
# 938:	learn: 0.0527075	total: 1m 13s	remaining: 4.8s
# 939:	learn: 0.0526995	total: 1m 14s	remaining: 4.72s
# 940:	learn: 0.0526836	total: 1m 14s	remaining: 4.65s
# 941:	learn: 0.0526748	total: 1m 14s	remaining: 4.57s
# 942:	learn: 0.0526618	total: 1m 14s	remaining: 4.49s
# 943:	learn: 0.0526549	total: 1m 14s	remaining: 4.41s
# 944:	learn: 0.0526480	total: 1m 14s	remaining: 4.33s
# 945:	learn: 0.0526451	total: 1m 14s	remaining: 4.25s
# 946:	learn: 0.0526384	total: 1m 14s	remaining: 4.17s
# 947:	learn: 0.0526250	total: 1m 14s	remaining: 4.09s
# 948:	learn: 0.0526033	total: 1m 14s	remaining: 4.02s
# 949:	learn: 0.0525976	total: 1m 14s	remaining: 3.94s
# 950:	learn: 0.0525887	total: 1m 14s	remaining: 3.86s
# 951:	learn: 0.0525854	total: 1m 14s	remaining: 3.78s
# 952:	learn: 0.0525793	total: 1m 15s	remaining: 3.7s
# 953:	learn: 0.0525675	total: 1m 15s	remaining: 3.62s
# 954:	learn: 0.0525581	total: 1m 15s	remaining: 3.54s
# 955:	learn: 0.0525501	total: 1m 15s	remaining: 3.46s
# 956:	learn: 0.0525429	total: 1m 15s	remaining: 3.39s
# 957:	learn: 0.0525370	total: 1m 15s	remaining: 3.31s
# 958:	learn: 0.0525284	total: 1m 15s	remaining: 3.23s
# 959:	learn: 0.0525183	total: 1m 15s	remaining: 3.15s
# 960:	learn: 0.0524950	total: 1m 15s	remaining: 3.07s
# 961:	learn: 0.0524885	total: 1m 15s	remaining: 2.99s
# 962:	learn: 0.0524845	total: 1m 15s	remaining: 2.91s
# 963:	learn: 0.0524767	total: 1m 15s	remaining: 2.83s
# 964:	learn: 0.0524059	total: 1m 15s	remaining: 2.76s
# 965:	learn: 0.0523987	total: 1m 16s	remaining: 2.68s
# 966:	learn: 0.0523898	total: 1m 16s	remaining: 2.6s
# 967:	learn: 0.0523830	total: 1m 16s	remaining: 2.52s
# 968:	learn: 0.0523689	total: 1m 16s	remaining: 2.44s
# 969:	learn: 0.0523517	total: 1m 16s	remaining: 2.36s
# 970:	learn: 0.0523475	total: 1m 16s	remaining: 2.28s
# 971:	learn: 0.0523412	total: 1m 16s	remaining: 2.21s
# 972:	learn: 0.0523337	total: 1m 16s	remaining: 2.13s
# 973:	learn: 0.0523295	total: 1m 16s	remaining: 2.05s
# 974:	learn: 0.0523240	total: 1m 16s	remaining: 1.97s
# 975:	learn: 0.0523163	total: 1m 16s	remaining: 1.89s
# 976:	learn: 0.0523086	total: 1m 16s	remaining: 1.81s
# 977:	learn: 0.0523010	total: 1m 17s	remaining: 1.73s
# 978:	learn: 0.0522959	total: 1m 17s	remaining: 1.65s
# 979:	learn: 0.0522869	total: 1m 17s	remaining: 1.57s
# 980:	learn: 0.0522796	total: 1m 17s	remaining: 1.5s
# 981:	learn: 0.0522745	total: 1m 17s	remaining: 1.42s
# 982:	learn: 0.0522707	total: 1m 17s	remaining: 1.34s
# 983:	learn: 0.0522657	total: 1m 17s	remaining: 1.26s
# 984:	learn: 0.0522565	total: 1m 17s	remaining: 1.18s
# 985:	learn: 0.0522475	total: 1m 17s	remaining: 1.1s
# 986:	learn: 0.0522415	total: 1m 17s	remaining: 1.02s
# 987:	learn: 0.0522078	total: 1m 17s	remaining: 945ms
# 988:	learn: 0.0522005	total: 1m 17s	remaining: 866ms
# 989:	learn: 0.0521968	total: 1m 17s	remaining: 788ms
# 990:	learn: 0.0521931	total: 1m 18s	remaining: 709ms
# 991:	learn: 0.0521833	total: 1m 18s	remaining: 630ms
# 992:	learn: 0.0521777	total: 1m 18s	remaining: 551ms
# 993:	learn: 0.0521707	total: 1m 18s	remaining: 473ms
# 994:	learn: 0.0521655	total: 1m 18s	remaining: 394ms
# 995:	learn: 0.0521615	total: 1m 18s	remaining: 315ms
# 996:	learn: 0.0521519	total: 1m 18s	remaining: 236ms
# 997:	learn: 0.0521461	total: 1m 18s	remaining: 158ms
# 998:	learn: 0.0521390	total: 1m 18s	remaining: 78.8ms
# 999:	learn: 0.0521325	total: 1m 18s	remaining: 0us

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

lgb_pred = lgb_model.predict(validX[sel_features])
xgb_pred = xgb_model.predict(validX[sel_features])
linear_pred = linear_reg.predict(validX[sel_features])
cat_pred = cat_model.predict(validX[sel_features])

print(f"LightGBM loss(MSE) : {mean_squared_error(validY,lgb_pred)}")
print(f"XGBoost loss(MSE)  : {mean_squared_error(validY,xgb_pred)}")
print(f"Linear loss(MSE)  : {mean_squared_error(validY,linear_pred)}")
print(f"CatBoost loss(MSE)  : {mean_squared_error(validY,cat_pred)}")
print()

print(f"LightGBM loss(MAE) : {mean_absolute_error(validY,lgb_pred)}")
print(f"XGBoost loss(MAE)  : {mean_absolute_error(validY,xgb_pred)}")
print(f"Linear loss(MAE)  : {mean_absolute_error(validY,linear_pred)}")
print(f"CatBoost loss(MAE)  : {mean_absolute_error(validY,cat_pred)}")
# Out:
# LightGBM loss(MSE) : 0.012655644533465743
# XGBoost loss(MSE)  : 0.019861045556659445
# Linear loss(MSE)  : 0.026046667230799625
# CatBoost loss(MSE)  : 0.01431464828987269
#
# LightGBM loss(MAE) : 0.04998423402610429
# XGBoost loss(MAE)  : 0.07417684061655529
# Linear loss(MAE)  : 0.10109492926538104
# CatBoost loss(MAE)  : 0.05064907377867848

# %%
from datetime import datetime
import numpy as np
from sklearn.metrics import mean_squared_error


def date_range(start, end):
    start = datetime.strptime(start, "%Y%m%d")
    end = datetime.strptime(end, "%Y%m%d")
    dates = [date.strftime("%Y%m%d") for date in pd.date_range(start, periods=(end-start).days+1)]
    return dates

path = "./forecasting_data/"

save_f = "./figure/" + label + "/"

for valid_date in valid_dates:
    try:
        valid = pd.read_feather(path + valid_date + "/rack.feather")[sel_features]

        validX = valid.iloc[:-600,:]
        validY = valid.reset_index(drop=True).loc[600:,label].reset_index(drop=True)

        lgb_pred = lgb_model.predict(validX)
        xgb_pred = xgb_model.predict(validX)
        linear_pred = linear_reg.predict(validX)
        cat_pred = cat_model.predict(validX)
    except:
        continue
    '''
    plt.subplot(2,3,1)
    plt.hist(validY, range=(3.2,4.2), color = 'b', label = 'original')
    
    plt.subplot(2,3,2)
    plt.hist(lgb_pred, range=(3.2,4.2), color = 'orange', label = 'prediction(LightGBM)')
    
    plt.subplot(2,3,3)
    plt.hist(xgb_pred, range=(3.2,4.2), color = 'green', label = 'prediction(XGBoost)')
    
    plt.subplot(2,3,6)
    plt.plot(range(len(validY)),validY, color='black', label = 'original')
    
    
    ax0 = plt.subplot2grid((2, 3), (0, 0), rowspan=1, colspan=1)
    ax1 = plt.subplot2grid((2, 3), (0, 1), rowspan=1, colspan=1)
    ax2 = plt.subplot2grid((2, 3), (0, 2), rowspan=1, colspan=1)
    ax3 = plt.subplot2grid((2, 3), (1, 0), rowspan=1, colspan=3)

    ax0.hist(validY, range=(3.2,4.2), color = 'b', label = 'original')
    ax1.hist(lgb_pred, range=(3.2,4.2), color = 'orange', label = 'LightGBM')
    #ax2.hist(xgb_pred, range=(3.2,4.2), color = 'green', label = 'XGBoost')
    ax2.hist(linear_pred, range=(3.2,4.2), color = 'green', label = 'Linear')
    
    length = len(validY)
    ax3.plot(range(len(validY)),validY, color='black', label = 'original')
    ax3.plot(range(600,length+600), lgb_pred, color = 'orange', label = 'prediction')
    #ax3.plot(range(600,length+600), xgb_pred, color = 'green', label = 'prediction')
    ax3.plot(range(600,length+600), linear_pred, color = 'green', label = 'prediction')
    
    ax0.legend(loc='upper left')
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper left')
    '''
    length = len(validY)
    
    plt.plot(range(len(validY)),validY, color='black', label = 'original')
    plt.plot(range(600,length+600), lgb_pred, color = 'r', linewidth = 0.5, label = 'LightGBM')
    plt.plot(range(600,length+600), xgb_pred, color = 'g', linewidth = 0.5, label = 'XGBoost')
    plt.plot(range(600,length+600), linear_pred, color = 'b', linewidth = 0.5, label = 'Linear')
    plt.plot(range(600,length+600), cat_pred, color = 'orange', linewidth = 0.5, label = 'catBoost')
    
    plt.legend()
    
    plt.title(valid_date)
    
    plt.tight_layout()
    plt.savefig(save_f+f"{valid_date}.jpg", dpi=600)
    
    plt.show()

# %%
import joblib

save_model_path = "./model/" + label + "/"

joblib.dump(lgb_model, save_model_path + "lgb_model.pkl") 
joblib.dump(xgb_model, save_model_path + "xgb_model.pkl") 
joblib.dump(linear_reg, save_model_path + "linear_model.pkl") 
joblib.dump(cat_model, save_model_path + "cat_model.pkl")
# Out:
# ['./model/RACK_MAX_CELL_TEMPERATURE/cat_model.pkl']
