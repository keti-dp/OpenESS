# %%
import os
import glob
import math
import random
import json
import argparse
import numpy as np
from tqdm import tqdm
from datetime import datetime

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd

from model import lstm_generator

# %%
# data = '/home/jan4021/study/NCIA_ESS/Forecasting/data/SoC_synthesis2/20220424/20220424_concat.npy'

datas = glob.glob("data/SoC_synthesis3/*/*.npy")
datas.sort()
for data in datas:
    print(data)
    data = np.load(data)

    for i in range(11):
        plt.plot(data[i*86400 + 45000:(i+1)*86400 -4000,2])
    plt.show()
# Out:
# data/SoC_synthesis3/20220308/20220308_concat.npy
# data/SoC_synthesis3/20220316/20220316_concat.npy
# data/SoC_synthesis3/20220322/20220322_concat.npy
# data/SoC_synthesis3/20220328/20220328_concat.npy
# data/SoC_synthesis3/20220402/20220402_concat.npy
# data/SoC_synthesis3/20220403/20220403_concat.npy
# data/SoC_synthesis3/20220406/20220406_concat.npy
# data/SoC_synthesis3/20220407/20220407_concat.npy
# data/SoC_synthesis3/20220408/20220408_concat.npy
# data/SoC_synthesis3/20220412/20220412_concat.npy
# data/SoC_synthesis3/20220415/20220415_concat.npy
# data/SoC_synthesis3/20220416/20220416_concat.npy
# data/SoC_synthesis3/20220419/20220419_concat.npy
# data/SoC_synthesis3/20220420/20220420_concat.npy
# data/SoC_synthesis3/20220424/20220424_concat.npy
# data/SoC_synthesis3/20220502/20220502_concat.npy
# data/SoC_synthesis3/20220504/20220504_concat.npy
# data/SoC_synthesis3/20220508/20220508_concat.npy
# data/SoC_synthesis3/20220510/20220510_concat.npy
